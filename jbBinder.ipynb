# %%
! jupyter-book build ce4353workbook/
# Out:
# Running Jupyter-Book v0.12.0
# Source Folder: /home/sensei/ce-4353-webroot/ce4353workbook
# Config Path: /home/sensei/ce-4353-webroot/ce4353workbook/_config.yml
# Output Path: /home/sensei/ce-4353-webroot/ce4353workbook/_build/html
# Running Sphinx v3.5.2
# [etoc] Changing master_doc to 'intro'
# loading pickled environment... checking for /home/sensei/ce-4353-webroot/ce4353workbook/references.bib in bibtex cache... up to date
# done
# ...
